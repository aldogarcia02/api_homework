# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time

# Import API key
from api_keys import api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 591

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
City = []
Cloudiness = []
Country = []
Date = []
Humidity = []
Lat = []
Lon = []
Max_Temp = []
Wind_Speed = []

# Starting the record count as 1
record_count = 1
units = "metric"
print('''
Beginning and verifying the city retrieval
------------------------------------------
''')
base_url = "http://api.openweathermap.org/data/2.5/weather?"
for c in cities:
    try:
        base_url = "http://api.openweathermap.org/data/2.5/weather?"
        # Starting with the url and getting it to append to each city
        query_url = f"{base_url}appid={api_key}&units={units}&q={c}"
        response = requests.get(query_url).json()
        print(f"Sanity Checking the URL\n{query_url}")
        
        # Appending each list as declared above
        City.append(response['name'])
        Cloudiness.append(response['clouds']['all'])
        Country.append(response['sys']['country'])
        Date.append(response['dt'])
        Humidity.append(response['main']['humidity'])
        Lat.append(response['coord']['lat'])
        Lon.append(response['coord']['lat'])
        Max_Temp.append(response['main']['temp_max'])
        Wind_Speed.append(response['wind']['speed'])
        
        c_fixed = c.replace("+"," ")
        
        print(f"\nRecord {record_count} of Set 1 | {c_fixed}")
        print("--------------------------")
        
        # Adding up on the record
        record_count += 1
        
      
        
        time.sleep(1.5)
    except:

        print(f"\nWas not found: {c}")


        print("--------------------------")
    continue
# Out:
# Beginning and verifying the city retrieval
# ------------------------------------------
#
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bubaque
#
# Record 1 of Set 1 | bubaque
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=rikitea
#
# Record 2 of Set 1 | rikitea
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=new norfolk
#
# Record 3 of Set 1 | new norfolk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=anupshahr
#
# Record 4 of Set 1 | anupshahr
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tasiilaq
#
# Record 5 of Set 1 | tasiilaq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=vostok
#
# Record 6 of Set 1 | vostok
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=carnarvon
#
# Record 7 of Set 1 | carnarvon
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=shetpe
#
# Record 8 of Set 1 | shetpe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=faanui
#
# Record 9 of Set 1 | faanui
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tsihombe
#
# Was not found: tsihombe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mataura
#
# Record 10 of Set 1 | mataura
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=port hardy
#
# Record 11 of Set 1 | port hardy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=gagra
#
# Record 12 of Set 1 | gagra
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kamina
#
# Record 13 of Set 1 | kamina
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=flinders
#
# Record 14 of Set 1 | flinders
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hilo
#
# Record 15 of Set 1 | hilo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ancud
#
# Record 16 of Set 1 | ancud
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=fortuna
#
# Record 17 of Set 1 | fortuna
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=alihe
#
# Record 18 of Set 1 | alihe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=avarua
#
# Record 19 of Set 1 | avarua
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kapaa
#
# Record 20 of Set 1 | kapaa
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=luderitz
#
# Record 21 of Set 1 | luderitz
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ushuaia
#
# Record 22 of Set 1 | ushuaia
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=amderma
#
# Was not found: amderma
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=jamestown
#
# Record 23 of Set 1 | jamestown
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mahon
#
# Record 24 of Set 1 | mahon
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=yellowknife
#
# Record 25 of Set 1 | yellowknife
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=pevek
#
# Record 26 of Set 1 | pevek
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=iqaluit
#
# Record 27 of Set 1 | iqaluit
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mahebourg
#
# Record 28 of Set 1 | mahebourg
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=longyearbyen
#
# Record 29 of Set 1 | longyearbyen
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=puerto ayora
#
# Record 30 of Set 1 | puerto ayora
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=boda
#
# Record 31 of Set 1 | boda
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=norman wells
#
# Record 32 of Set 1 | norman wells
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=vaini
#
# Record 33 of Set 1 | vaini
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=taoudenni
#
# Record 34 of Set 1 | taoudenni
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=roebourne
#
# Record 35 of Set 1 | roebourne
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bilma
#
# Record 36 of Set 1 | bilma
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=turukhansk
#
# Record 37 of Set 1 | turukhansk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=atuona
#
# Record 38 of Set 1 | atuona
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=waslala
#
# Record 39 of Set 1 | waslala
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=troitsko-pechorsk
#
# Record 40 of Set 1 | troitsko-pechorsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=punta alta
#
# Record 41 of Set 1 | punta alta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kodiak
#
# Record 42 of Set 1 | kodiak
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=riyadh
#
# Record 43 of Set 1 | riyadh
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=saskylakh
#
# Record 44 of Set 1 | saskylakh
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kaitangata
#
# Record 45 of Set 1 | kaitangata
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=simpang
#
# Record 46 of Set 1 | simpang
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=cabo san lucas
#
# Record 47 of Set 1 | cabo san lucas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=namatanai
#
# Record 48 of Set 1 | namatanai
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=barentsburg
#
# Was not found: barentsburg
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=antofagasta
#
# Record 49 of Set 1 | antofagasta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=angoche
#
# Record 50 of Set 1 | angoche
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=muroto
#
# Record 51 of Set 1 | muroto
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=weyburn
#
# Record 52 of Set 1 | weyburn
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=busselton
#
# Record 53 of Set 1 | busselton
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bluff
#
# Record 54 of Set 1 | bluff
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=najran
#
# Record 55 of Set 1 | najran
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=chuy
#
# Record 56 of Set 1 | chuy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kourou
#
# Record 57 of Set 1 | kourou
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sao jose da coroa grande
#
# Record 58 of Set 1 | sao jose da coroa grande
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=port elizabeth
#
# Record 59 of Set 1 | port elizabeth
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=plettenberg bay
#
# Record 60 of Set 1 | plettenberg bay
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bredasdorp
#
# Record 61 of Set 1 | bredasdorp
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=barrow
#
# Record 62 of Set 1 | barrow
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=port lincoln
#
# Record 63 of Set 1 | port lincoln
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=taicheng
#
# Record 64 of Set 1 | taicheng
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=thompson
#
# Record 65 of Set 1 | thompson
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tamiahua
#
# Record 66 of Set 1 | tamiahua
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=cape town
#
# Record 67 of Set 1 | cape town
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ponta do sol
#
# Record 68 of Set 1 | ponta do sol
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=henderson
#
# Record 69 of Set 1 | henderson
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kromy
#
# Record 70 of Set 1 | kromy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hithadhoo
#
# Record 71 of Set 1 | hithadhoo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=klaksvik
#
# Record 72 of Set 1 | klaksvik
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ribeira grande
#
# Record 73 of Set 1 | ribeira grande
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=georgetown
#
# Record 74 of Set 1 | georgetown
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=khash
#
# Record 75 of Set 1 | khash
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hermanus
#
# Record 76 of Set 1 | hermanus
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=namibe
#
# Record 77 of Set 1 | namibe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=attawapiskat
#
# Was not found: attawapiskat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=williamsburg
#
# Record 78 of Set 1 | williamsburg
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=nhulunbuy
#
# Record 79 of Set 1 | nhulunbuy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=louisbourg
#
# Was not found: louisbourg
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=castro
#
# Record 80 of Set 1 | castro
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=nantucket
#
# Record 81 of Set 1 | nantucket
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hobart
#
# Record 82 of Set 1 | hobart
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=lebu
#
# Record 83 of Set 1 | lebu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=cap-aux-meules
#
# Record 84 of Set 1 | cap-aux-meules
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=souillac
#
# Record 85 of Set 1 | souillac
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=maniitsoq
#
# Record 86 of Set 1 | maniitsoq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=narsaq
#
# Record 87 of Set 1 | narsaq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=olafsvik
#
# Record 88 of Set 1 | olafsvik
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=poltavka
#
# Record 89 of Set 1 | poltavka
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=dikson
#
# Record 90 of Set 1 | dikson
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=nikolskoye
#
# Record 91 of Set 1 | nikolskoye
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=akdepe
#
# Record 92 of Set 1 | akdepe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=arraial do cabo
#
# Record 93 of Set 1 | arraial do cabo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=gambo
#
# Record 94 of Set 1 | gambo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mahanoro
#
# Record 95 of Set 1 | mahanoro
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ahipara
#
# Record 96 of Set 1 | ahipara
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=batagay-alyta
#
# Record 97 of Set 1 | batagay-alyta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=livenka
#
# Record 98 of Set 1 | livenka
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=lavrentiya
#
# Record 99 of Set 1 | lavrentiya
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ponta delgada
#
# Record 100 of Set 1 | ponta delgada
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=havoysund
#
# Record 101 of Set 1 | havoysund
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=zambezi
#
# Record 102 of Set 1 | zambezi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kettering
#
# Record 103 of Set 1 | kettering
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tungkang
#
# Was not found: tungkang
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=katsuura
#
# Record 104 of Set 1 | katsuura
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kerema
#
# Record 105 of Set 1 | kerema
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=port alfred
#
# Record 106 of Set 1 | port alfred
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=teul
#
# Was not found: teul
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=airai
#
# Record 107 of Set 1 | airai
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=manbij
#
# Record 108 of Set 1 | manbij
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=qaanaaq
#
# Record 109 of Set 1 | qaanaaq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=abbeville
#
# Record 110 of Set 1 | abbeville
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tuatapere
#
# Record 111 of Set 1 | tuatapere
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=muros
#
# Record 112 of Set 1 | muros
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=buala
#
# Record 113 of Set 1 | buala
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=la ronge
#
# Record 114 of Set 1 | la ronge
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=dukat
#
# Record 115 of Set 1 | dukat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=saldanha
#
# Record 116 of Set 1 | saldanha
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mizan teferi
#
# Record 117 of Set 1 | mizan teferi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=lasa
#
# Record 118 of Set 1 | lasa
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=taltal
#
# Record 119 of Set 1 | taltal
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mar del plata
#
# Record 120 of Set 1 | mar del plata
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=magdalena
#
# Record 121 of Set 1 | magdalena
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sao miguel do araguaia
#
# Record 122 of Set 1 | sao miguel do araguaia
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=faya
#
# Record 123 of Set 1 | faya
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=dordrecht
#
# Record 124 of Set 1 | dordrecht
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hofn
#
# Record 125 of Set 1 | hofn
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kyaikkami
#
# Record 126 of Set 1 | kyaikkami
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=rodionovo-nesvetayskaya
#
# Record 127 of Set 1 | rodionovo-nesvetayskaya
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=price
#
# Record 128 of Set 1 | price
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hoa binh
#
# Record 129 of Set 1 | hoa binh
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sistranda
#
# Record 130 of Set 1 | sistranda
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=codrington
#
# Record 131 of Set 1 | codrington
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=leningradskiy
#
# Record 132 of Set 1 | leningradskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=belaya gora
#
# Record 133 of Set 1 | belaya gora
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=punta arenas
#
# Record 134 of Set 1 | punta arenas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=belushya guba
#
# Was not found: belushya guba
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=alofi
#
# Record 135 of Set 1 | alofi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ngukurr
#
# Was not found: ngukurr
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mazara del vallo
#
# Record 136 of Set 1 | mazara del vallo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=gornyak
#
# Record 137 of Set 1 | gornyak
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=azrow
#
# Was not found: azrow
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=albany
#
# Record 138 of Set 1 | albany
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=esperance
#
# Record 139 of Set 1 | esperance
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=beringovskiy
#
# Record 140 of Set 1 | beringovskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bahia de caraquez
#
# Record 141 of Set 1 | bahia de caraquez
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=srednekolymsk
#
# Record 142 of Set 1 | srednekolymsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=maroantsetra
#
# Record 143 of Set 1 | maroantsetra
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sept-iles
#
# Record 144 of Set 1 | sept-iles
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=yuci
#
# Record 145 of Set 1 | yuci
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=boyolangu
#
# Record 146 of Set 1 | boyolangu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=huntsville
#
# Record 147 of Set 1 | huntsville
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bowen
#
# Record 148 of Set 1 | bowen
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=clyde river
#
# Record 149 of Set 1 | clyde river
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=butaritari
#
# Record 150 of Set 1 | butaritari
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kosh-agach
#
# Record 151 of Set 1 | kosh-agach
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=carbonia
#
# Record 152 of Set 1 | carbonia
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=algiers
#
# Record 153 of Set 1 | algiers
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=laguna
#
# Record 154 of Set 1 | laguna
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=taolanaro
#
# Was not found: taolanaro
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=pousat
#
# Was not found: pousat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=prince rupert
#
# Record 155 of Set 1 | prince rupert
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=anadyr
#
# Record 156 of Set 1 | anadyr
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bandarbeyla
#
# Record 157 of Set 1 | bandarbeyla
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=itaueira
#
# Record 158 of Set 1 | itaueira
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kavieng
#
# Record 159 of Set 1 | kavieng
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=san patricio
#
# Record 160 of Set 1 | san patricio
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=maine-soroa
#
# Record 161 of Set 1 | maine-soroa
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mehamn
#
# Record 162 of Set 1 | mehamn
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=chokurdakh
#
# Record 163 of Set 1 | chokurdakh
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mangrol
#
# Record 164 of Set 1 | mangrol
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=brewster
#
# Record 165 of Set 1 | brewster
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ternate
#
# Record 166 of Set 1 | ternate
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=purpe
#
# Record 167 of Set 1 | purpe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=caravelas
#
# Record 168 of Set 1 | caravelas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=illoqqortoormiut
#
# Was not found: illoqqortoormiut
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bone
#
# Record 169 of Set 1 | bone
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=khatanga
#
# Record 170 of Set 1 | khatanga
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bara
#
# Record 171 of Set 1 | bara
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=cayenne
#
# Record 172 of Set 1 | cayenne
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=alyangula
#
# Record 173 of Set 1 | alyangula
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=teruel
#
# Record 174 of Set 1 | teruel
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=salalah
#
# Record 175 of Set 1 | salalah
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=scarborough
#
# Record 176 of Set 1 | scarborough
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=portland
#
# Record 177 of Set 1 | portland
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tautira
#
# Record 178 of Set 1 | tautira
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=torbay
#
# Record 179 of Set 1 | torbay
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tiksi
#
# Record 180 of Set 1 | tiksi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=san joaquin
#
# Record 181 of Set 1 | san joaquin
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=vilyuysk
#
# Record 182 of Set 1 | vilyuysk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=cochrane
#
# Record 183 of Set 1 | cochrane
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=anjiang
#
# Record 184 of Set 1 | anjiang
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=egvekinot
#
# Record 185 of Set 1 | egvekinot
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=juneau
#
# Record 186 of Set 1 | juneau
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=gornopravdinsk
#
# Record 187 of Set 1 | gornopravdinsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=talnakh
#
# Record 188 of Set 1 | talnakh
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tayoltita
#
# Record 189 of Set 1 | tayoltita
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=cidreira
#
# Record 190 of Set 1 | cidreira
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bambous virieux
#
# Record 191 of Set 1 | bambous virieux
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=zhuhai
#
# Record 192 of Set 1 | zhuhai
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=cairns
#
# Record 193 of Set 1 | cairns
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=puli
#
# Record 194 of Set 1 | puli
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=puyang
#
# Record 195 of Set 1 | puyang
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=acuna
#
# Was not found: acuna
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kasongo-lunda
#
# Record 196 of Set 1 | kasongo-lunda
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sao filipe
#
# Record 197 of Set 1 | sao filipe
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=krabi
#
# Record 198 of Set 1 | krabi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=karratha
#
# Record 199 of Set 1 | karratha
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kupang
#
# Record 200 of Set 1 | kupang
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tura
#
# Record 201 of Set 1 | tura
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=asfi
#
# Record 202 of Set 1 | asfi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hasaki
#
# Record 203 of Set 1 | hasaki
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=villeneuve-sur-lot
#
# Record 204 of Set 1 | villeneuve-sur-lot
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=lompoc
#
# Record 205 of Set 1 | lompoc
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=baruun-urt
#
# Record 206 of Set 1 | baruun-urt
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hobyo
#
# Record 207 of Set 1 | hobyo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=skerries
#
# Record 208 of Set 1 | skerries
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=taloqan
#
# Record 209 of Set 1 | taloqan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kannur
#
# Record 210 of Set 1 | kannur
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hamilton
#
# Record 211 of Set 1 | hamilton
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=samana
#
# Record 212 of Set 1 | samana
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=touros
#
# Record 213 of Set 1 | touros
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=caronport
#
# Record 214 of Set 1 | caronport
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=rudnichnyy
#
# Record 215 of Set 1 | rudnichnyy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=galiwinku
#
# Was not found: galiwinku
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=noshiro
#
# Record 216 of Set 1 | noshiro
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=nurobod
#
# Record 217 of Set 1 | nurobod
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=comodoro rivadavia
#
# Record 218 of Set 1 | comodoro rivadavia
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=nizhneyansk
#
# Was not found: nizhneyansk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ust-tsilma
#
# Record 219 of Set 1 | ust-tsilma
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=paamiut
#
# Record 220 of Set 1 | paamiut
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ilulissat
#
# Record 221 of Set 1 | ilulissat
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tanabi
#
# Record 222 of Set 1 | tanabi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=saint pete beach
#
# Record 223 of Set 1 | saint pete beach
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=korla
#
# Record 224 of Set 1 | korla
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=matagami
#
# Record 225 of Set 1 | matagami
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ewa beach
#
# Record 226 of Set 1 | ewa beach
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=qaqortoq
#
# Record 227 of Set 1 | qaqortoq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=marcona
#
# Was not found: marcona
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=dokka
#
# Record 228 of Set 1 | dokka
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kem
#
# Record 229 of Set 1 | kem
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=grand river south east
#
# Was not found: grand river south east
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=buchanan
#
# Record 230 of Set 1 | buchanan
# --------------------------
# Sanity Checking the URL
# ...
#
# Record 467 of Set 1 | oda
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=victoria
#
# Record 468 of Set 1 | victoria
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=pacifica
#
# Record 469 of Set 1 | pacifica
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mana
#
# Record 470 of Set 1 | mana
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=coquimbo
#
# Record 471 of Set 1 | coquimbo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=nabire
#
# Record 472 of Set 1 | nabire
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=vestmannaeyjar
#
# Record 473 of Set 1 | vestmannaeyjar
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mainz
#
# Record 474 of Set 1 | mainz
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sonoma
#
# Record 475 of Set 1 | sonoma
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kayiry
#
# Record 476 of Set 1 | kayiry
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=arlit
#
# Record 477 of Set 1 | arlit
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sa kaeo
#
# Record 478 of Set 1 | sa kaeo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=promyshlennyy
#
# Record 479 of Set 1 | promyshlennyy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sorland
#
# Record 480 of Set 1 | sorland
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=verkhoyansk
#
# Record 481 of Set 1 | verkhoyansk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=erzin
#
# Record 482 of Set 1 | erzin
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mapimi
#
# Record 483 of Set 1 | mapimi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=wagga wagga
#
# Record 484 of Set 1 | wagga wagga
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=yambio
#
# Record 485 of Set 1 | yambio
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=isiro
#
# Record 486 of Set 1 | isiro
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=guaymas
#
# Record 487 of Set 1 | guaymas
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=shingu
#
# Record 488 of Set 1 | shingu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ostrovnoy
#
# Record 489 of Set 1 | ostrovnoy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=waingapu
#
# Record 490 of Set 1 | waingapu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=nisia floresta
#
# Record 491 of Set 1 | nisia floresta
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=suluq
#
# Record 492 of Set 1 | suluq
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=huari
#
# Record 493 of Set 1 | huari
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=burnie
#
# Record 494 of Set 1 | burnie
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=llanes
#
# Record 495 of Set 1 | llanes
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=santa maria
#
# Record 496 of Set 1 | santa maria
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=solovetskiy
#
# Was not found: solovetskiy
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=dingle
#
# Record 497 of Set 1 | dingle
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tezpur
#
# Record 498 of Set 1 | tezpur
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ixtapa
#
# Record 499 of Set 1 | ixtapa
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=chara
#
# Record 500 of Set 1 | chara
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mufulira
#
# Record 501 of Set 1 | mufulira
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=goba
#
# Record 502 of Set 1 | goba
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=eenhana
#
# Record 503 of Set 1 | eenhana
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ketchikan
#
# Record 504 of Set 1 | ketchikan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=forbes
#
# Record 505 of Set 1 | forbes
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kismayo
#
# Record 506 of Set 1 | kismayo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=del rio
#
# Record 507 of Set 1 | del rio
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tromso
#
# Record 508 of Set 1 | tromso
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=canico
#
# Record 509 of Set 1 | canico
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=aklavik
#
# Record 510 of Set 1 | aklavik
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=lolua
#
# Was not found: lolua
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=lagos
#
# Record 511 of Set 1 | lagos
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sarahan
#
# Record 512 of Set 1 | sarahan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=luan
#
# Record 513 of Set 1 | luan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hualmay
#
# Record 514 of Set 1 | hualmay
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=umzimvubu
#
# Was not found: umzimvubu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=awjilah
#
# Record 515 of Set 1 | awjilah
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=drayton valley
#
# Record 516 of Set 1 | drayton valley
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=labelle
#
# Record 517 of Set 1 | labelle
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=bacolod
#
# Record 518 of Set 1 | bacolod
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=ghanzi
#
# Record 519 of Set 1 | ghanzi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=reconquista
#
# Record 520 of Set 1 | reconquista
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=burica
#
# Was not found: burica
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mayo
#
# Record 521 of Set 1 | mayo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=adrar
#
# Record 522 of Set 1 | adrar
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=fallon
#
# Record 523 of Set 1 | fallon
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=matadi
#
# Record 524 of Set 1 | matadi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=hihifo
#
# Was not found: hihifo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=talavera de la reina
#
# Record 525 of Set 1 | talavera de la reina
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=gurskoye
#
# Was not found: gurskoye
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kruisfontein
#
# Record 526 of Set 1 | kruisfontein
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=vilhena
#
# Record 527 of Set 1 | vilhena
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=luwuk
#
# Record 528 of Set 1 | luwuk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=kattivakkam
#
# Record 529 of Set 1 | kattivakkam
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=yeniseysk
#
# Record 530 of Set 1 | yeniseysk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=moron
#
# Record 531 of Set 1 | moron
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=taksimo
#
# Record 532 of Set 1 | taksimo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=sobolevo
#
# Record 533 of Set 1 | sobolevo
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=zhigansk
#
# Record 534 of Set 1 | zhigansk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=richards bay
#
# Record 535 of Set 1 | richards bay
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=khonuu
#
# Was not found: khonuu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=muzhi
#
# Record 536 of Set 1 | muzhi
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=tulln
#
# Record 537 of Set 1 | tulln
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=derzhavinsk
#
# Record 538 of Set 1 | derzhavinsk
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=omsukchan
#
# Record 539 of Set 1 | omsukchan
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=daru
#
# Record 540 of Set 1 | daru
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=rio gallegos
#
# Record 541 of Set 1 | rio gallegos
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=pitimbu
#
# Record 542 of Set 1 | pitimbu
# --------------------------
# Sanity Checking the URL
# http://api.openweathermap.org/data/2.5/weather?appid=fac24ee030b2a4a4d846167e98ff19cb&units=metric&q=mango
#
# Record 543 of Set 1 | mango
# --------------------------

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
df = pd.DataFrame({
    "City":City,
    "Cloudiness":Cloudiness,
    "Country":Country,
    "Date":Date,
    "Humidity":Humidity,
    "Lat":Lat,
    "Lon":Lon,
    "Max_Temp":Max_Temp,
    "Wind_Speed":Wind_Speed})
df.count()
# Out:
# City          543
# Cloudiness    543
# Country       543
# Date          543
# Humidity      543
# Lat           543
# Lon           543
# Max_Temp      543
# Wind_Speed    543
# dtype: int64

# %%
df.head()
# Out:
#           City  Cloudiness Country        Date  Humidity    Lat    Lon  \
# 0      Bubaque           0      GW  1581544763        70  11.28  11.28
# 1      Rikitea         100      PF  1581544287        78 -23.12 -23.12
# 2  New Norfolk          90      AU  1581544766        76 -42.78 -42.78
# 3    Anupshahr           1      IN  1581544768        71  28.37  28.37
# 4     Tasiilaq         100      GL  1581544557        82  65.61  65.61
#
#    Max_Temp  Wind_Speed
# 0     26.63        7.11
# 1     26.17        7.83
# 2     15.56        1.50
# 3     13.81        4.24
# 4     -8.51       17.74

# %%
df.to_csv("Cities_&_weather_stats.csv")

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
from datetime import datetime as dt
print(dt.today())
# Out:
# 2020-02-12 14:15:46.154285

# %%
fig1, ax1 = plt.subplots()
latitude = df.Lat
temperature = df.Max_Temp
ax1.scatter(latitude, temperature, marker='o', edgecolors='black')
ax1.set_title(f"City Latitude vs. Max Temperature ({dt.today()})")
ax1.set_xlabel("City Latitude")
ax1.set_ylabel("Max Temperature ($^\circ$C)")
ax1.grid(axis='both')
fig1.savefig("Fig 1 - City Latitude vs. Max Temperature.png")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
fig2, ax2 = plt.subplots()
latitude = df.Lat
humidity = df.Humidity
ax2.scatter(latitude, humidity, marker='o', edgecolors='black')
ax2.set_title(f"City Latitude vs. Humidity ({dt.today()})")
ax2.set_xlabel("City Latitude")
ax2.set_ylabel("Humidity (%)")
ax2.grid(axis='both')
fig2.savefig(f"Fig 2 - City Latitude vs. Humidity.png")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
fig3, ax3 = plt.subplots()
latitude = df.Lat
cloudiness = df.Cloudiness
ax3.scatter(latitude, humidity, marker='o', edgecolors='black')
ax3.set_title(f"City Latitude vs. Cloudiness ({dt.today()})")
ax3.set_xlabel("City Latitude")
ax3.set_ylabel("Cloudiness (%)")
ax3.grid(axis='both')
fig3.savefig(f"Fig 3 - City Latitude vs. Cloudiness.png")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
fig4, ax4 = plt.subplots()
latitude = df.Lat
wind_speed = df.Wind_Speed
ax4.scatter(latitude, wind_speed, marker='o', edgecolors='black')
ax4.set_title(f"City Latitude vs. Wind Speed ({dt.today()})")
ax4.set_xlabel("City Latitude")
ax4.set_ylabel("Wind Speed (ms$^{-1}$)")
ax4.grid(axis='both')
fig4.savefig(f"Fig 4 - City Latitude vs Wind Speed)")
